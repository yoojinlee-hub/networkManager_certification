# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/Rout34_Setting_IP_Address.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Router 1의 FastEthernet 0/0의 IP Address를 아래와 같이 설정하고 활성화 하시오
#
# *  ip address: 192.168.100.1/24

# %% [markdown]
# ![화면 캡처 2021-09-19 100729.png](data:image/png;base64,...)

# %% [markdown]
# ip address 설정 : **ip add**

# %% [markdown]
# ---
