# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EB%A1%9C%EC%BB%AC%EC%82%AC%EC%9A%A9%EC%9E%90_%EB%B0%8F_%EA%B7%B8%EB%A3%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 사용자 계정 추가: ICQAUSER1
# 2. password : icqauser@#$
# 3. 소속 그룹: Remote Desktop Users

# %% [markdown]
# 사용자 오른쪽 클릭 -> 새 사용자![화면 캡처 2021-09-18 103709.png](data:image/png;base64,...)

# %% [markdown]
# 만들어진 계정 오른쪽 클릭 -> 속성 -> 그룹설정![화면 캡처 2021-09-18 103829.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# * 사용자 계정 추가: ICQANetwork
# * 전체이름 : 한국정보통신자격협회
# * 설명: 네트워크관리사2급
# * 비밀번호: ICQAPass
# * 사용자가 암호를 변경할 수 없음
# * 비밀번호 사용기한 제한 없음
# * 소속그룹: remote desktop users
# * 연결 끊긴 세션 끝내기 : 5분

# %% [markdown]
# ![화면 캡처 2021-09-26 114236.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-26 114311.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-26 114355.png](data:image/png;base64,...)

# %% [markdown]
# ---
