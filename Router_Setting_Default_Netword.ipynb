# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/Router_Setting_Default_Netword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RIP환경이 구성되어 있을 떄 라우팅 테이블에 등록되지 않는 목적지로 향하는 패킷은 192.168.1.1 네트워크로 보내도록 Router1에 디폴트 네트워크를 설정하시오.(단, ip route 0.0.0.0 명령어를 사용하면 안됨)

# %% [markdown]
# ![화면 캡처 2021-09-19 100156.png](data:image/png;base64,...)

# %% [markdown]
# default-gateway문제와 비슷하다

# %% [markdown]
# ---
