# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/Router_setting_access_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 네트워크가 구성되고 Router1에 access-list 1이 설정되어 있을 때 FastEthernet 0/0에 저장하시오<br>
# *패킷 이동방향은 양방향*

# %% [markdown]
# ![화면 캡처 2021-09-16 173802.png](data:image/png;base64,...)

# %% [markdown]
# fastethernet 0/0에 들어간 후 access list 설정: ***ip access-group 1 in/out***

# %% [markdown]
# ---
