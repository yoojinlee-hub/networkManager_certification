# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EC%84%9C%EB%B9%84%EC%8A%A4_%EC%84%A4%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 인터넷 정보 서비스 관리자를 사용하여 웹 연결 및 관리를 제공하는 서비스를 현재 시스템에서 '중지' 시키고, 시작유형을 '사용 안함'으로 설정하시오

# %% [markdown]
# ![화면 캡처 2021-09-14 135834.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 135902.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 제시문제와 같이 서비스를 '시작'시키고 시작유형을 '자동'으로 처리하시오.

# %% [markdown]
# 성능 로그 및 경고는 미리 구성된 일정 매개 변수에 따라 로컬 또는 원격 컴퓨터에서 성능데이터를 수집한 다음이 데이터를 로그에 기록하거나 경고를 트리거합니다. 이 서비스를 사용할 수 없게 하면 명확하게 이 서비스에 종속되는 모든 서비스가 시작되지 않습니다.

# %% [markdown]
# ![화면 캡처 2021-09-27 111327.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-27 111352.png](data:image/png;base64,...)

# %% [markdown]
# ---
