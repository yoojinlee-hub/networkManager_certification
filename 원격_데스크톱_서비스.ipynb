# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EC%9B%90%EA%B2%A9_%EB%8D%B0%EC%8A%A4%ED%81%AC%ED%86%B1_%EC%84%9C%EB%B9%84%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 네트워크 수준 인증을 사용하여 원격데스크톱을 실행하는 컴퓨터에서만 연결 허용
# 2. 세션 제한에 도달하거나 연결이 끊어지면 세션 끝내기
# 3. 원격제어 : 사용자의 허가 필요
# 4. Remote Desktop Users만 모든 권한 허용

# %% [markdown]
# 연결 이름 우클릭 <br>![화면 캡처 2021-09-27 113059.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-27 113150.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-27 113217.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-27 113246.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-27 113332.png](data:image/png;base64,...)

# %% [markdown]
# ---
