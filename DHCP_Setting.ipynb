# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/DHCP_Setting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <문제>: 아래의 보기와 같이 ip를 할당할 수 있는 dhcp를 설정하시오
#
# *   범위이름:네트워크관리사
# *   설명:한국정보통신자격협회
# * 분배할 주소 범위: 192.168.106.1~254
# * 제외할 주소 범위: 192.168.106.2~25
# * 임대기간:8일
# * 서브넷마스크: 255.255.255.0(24bit)
# * 게이트웨이 설정: 192.168.106.1
# * 예약 설정 <br>
# -- ip:192.168.106.200
# -- 예약이름:Example
# -- MAC주소: ff-ff-ff-ff-ff-ff
# -- 설명: 예약
#
# **모두 설정한 뒤 활성화하라**

# %% [markdown]
# ![화면 캡처 2021-09-07 193122.png](data:image/png;base64,...)

# %% [markdown]
# IPv4에서 마우스 오른쪽 -> 새 범위 메뉴![화면 캡처 2021-09-07 193234.png](data:image/png;base64,...)

# %% [markdown]
# **범위이름, 설명 설정**![화면 캡처 2021-09-07 193307.png](data:image/png;base64,...)

# %% [markdown]
# **ip 주소 범위 설정, 서브넷마스크 설정**![화면 캡처 2021-09-07 193401.png](data:image/png;base64,...)

# %% [markdown]
# **제외주소 추가**![화면 캡처 2021-09-07 193456.png](data:image/png;base64,...)

# %% [markdown]
# **임대기간 설정**![화면 캡처 2021-09-07 193514.png](data:image/png;base64,...)

# %% [markdown]
# ***옵션을 나중에 구성합니다!!!!!!!!***![화면 캡처 2021-09-07 193642.png](data:image/png;base64,...)

# %% [markdown]
# 예약 오른쪽 마우스 -> 새 예약 ![화면 캡처 2021-09-07 193757.png](data:image/png;base64,...)

# %% [markdown]
# ***활성화 시키기!***![화면 캡처 2021-09-07 193905.png](data:image/png;base64,...)

# %% [markdown]
# ***범위 누르고 오른쪽 마우스 -> 활성화***

# %% [markdown]
# 범위옵션 -> 옵션구성 : 라우터 체크 후 ip주소 입력,추가<br>https://ahngo13.tistory.com/275 참고

# %% [markdown]
# ---

# %% [markdown]
# 문제> 제시문제와 같이 ip를 할당할 수 있는 dhcp를 설정하시오.

# %% [markdown]
# 1. 범위이름: ICQA
# 2. 범위설정: 한국정보통신자격협회
# 3. 분배할 주소 범위: 192.168.100.1~254
# 4. 제외할 주소 범위 : 192.168.100.2~25
# 5. 임대기간 : 8시간

# %% [markdown]
# ![화면 캡처 2021-09-13 114952.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-13 115055.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-13 115145.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-13 115210.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 서버관리자 Park 사원은 Window Server 2016에서 DHCP Server를 이용하여 네트워크 환경을 구축하고자 한다.
# 1. 이름: Network
# 2. IP: 192.168.100.1 ~ 254
# 3. Subnet: 255.255.255.0
# 4. 제외 IP: 192.168.100.1~3
# 5. 임대 : 8시간
# 6. G/W: 192.168.100.1
# 7. Dns 1 : 192.168.100.2 <br>
#    Dns 2: 192.168.100.3

# %% [markdown]
# G/W = Gate Way

# %% [markdown]
# ![화면 캡처 2021-09-20 111623.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 111718.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 111752.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 111812.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 111841.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 111906.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 112002.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# DHCP를 설정하시오
#
# 1. 범위이름: 네트워크관리사
# 2. 범위 설명: 한국정보통신자격협회
# 3. 서브넷마스크: 24bit
# 4. 분배할 주소 범위: 192.168.100.1~254
# 5. 제외할 주소 범위: 192.168.100.2~25
# 6. 게이트웨이 설정: 192.168.100.1
# 7. 임대기간: 8시간

# %% [markdown]
# 24bit = 11111111.11111111.11111111.00000000 = 255.255.255.0

# %% [markdown]
# ![화면 캡처 2021-09-24 173636.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-24 173719.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-24 173749.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-24 173805.png](data:image/png;base64,...)

# %% [markdown]
# + 게이트웨이설정은 *예,지금구성합니다* 로 넘어가서 해야함

# %% [markdown]
# ---
