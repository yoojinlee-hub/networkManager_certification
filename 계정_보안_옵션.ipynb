# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EA%B3%84%EC%A0%95_%EB%B3%B4%EC%95%88_%EC%98%B5%EC%85%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Windows Server 2008 R2에서 administrator 계정 이름을 사용하는 경우, 악의적인 사용자들의 사전 대입공격이나 패스워드 추측 공격에 취약하게 된다. 또한 Guest 계정이 활성화 되어 있다면 Guest계정을 통한 많은 정보 획득도 가능하게 된다. <제시문제> 와 같이 로컬사용자에 대한 보안옵션을 설정하시오.
#
# *   Administrator 계정 이름 : icqaadmin
# *   Guest 계정은 사용 안함

# %% [markdown]
# ![화면 캡처 2021-09-14 141251.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 141311.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 141335.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 141351.png](data:image/png;base64,...)

# %% [markdown]
# ---
