# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EC%9B%B9%EC%82%AC%EC%9D%B4%ED%8A%B8_%EC%84%A4%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 문제> 제시문제와 같이 웹사이트를 추가 설정하시오

# %% [markdown]
# 1. 사이트이름: ICQA
# 2. ip주소: 210.160.120.230
# 3. 포트: 80
# 4. 호스트이름: www.icqa.co.kr
# 5. 경로: c:\inetpub\web

# %% [markdown]
# ![화면 캡처 2021-09-13 120126.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 2개의 Web 서버 설정 <br>
# **1번** <br>
# 1. 도메인명: www.icqa.or.kr
# 2. 사이트이름: ICQA
# 3. 실제 경로: C:\icqa
# 4. IP Adderss : 210.150.120.1
# 5. 포트: 80
#
# **2번** <br>
# 1. 도메인명: www.korea.or.kr
# 2. 사이트이름: Korea
# 3. 실제 경로: C:\korea
# 4. IP Adderss : 210.150.120.1
# 5. 포트: 80

# %% [markdown]
# ip address가 같기 때문에 ***바인딩 설정***을 해 줘야 한다

# %% [markdown]
# ![화면 캡처 2021-09-20 112707.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 112801.png](data:image/png;base64,...)

# %% [markdown]
# ICQA오른쪽 클릭 -> 바인딩 편집

# %% [markdown]
# ![화면 캡처 2021-09-20 112905.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# SiteName : ICQAWeb <br>
# Path: C:\icqa\inetpub<br>
# IP: 192.168.0.154<br>
# Port : 8080<br>
# Host Name: www.icqaweb.or.kr<br>
# Acess 허용 : 192.168.0.0/24<br>
# 기본문서: index.html만 사용

# %% [markdown]
# ![화면 캡처 2021-09-25 163317.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-25 163359.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-25 163441.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-25 163550.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-25 163626.png](data:image/png;base64,...)

# %% [markdown]
# ---
