# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/Router_setting_OSPF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 네트워크가 구성되어 있을 때 Router 1에 OSPF를 설정하시오(Process ID와 Area ID는 1)

# %% [markdown]
# ![화면 캡처 2021-09-16 174642.png](data:image/png;base64,...)

# %% [markdown]
# network 뒤에 ip주소 : 맨 뒤에는 0으로 바꿈(제시된 ip 주소: *192.70.100.1/24,193.150.60.50/24*)<br>24 : 0.0.0.255 **와일드마스크=서브넷마스크 뒤집기**
