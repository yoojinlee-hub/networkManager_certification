# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EC%84%A0%ED%83%9D%ED%98%95_%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 아래의 제시된 프로토콜 중 TCP/IP 4계층의 인터넷 계층에 해당되는 것을 모두 선택하시오
#
# *   ATM
# *   TCP
# * ARP
# * ICMP
# * SMTP
# * FTP
# * UDP
# * ICMP

# %% [markdown]
# <정답> TCP/IP 4계층 ![213F623C566BAE253B.png](data:image/png;base64,...)

# %% [markdown]
# TCP IP L2 : 인터넷 계층 = OSI 3계층 네트워크 계층
# <br>프로토콜 : IP, ARP, RARP,ICMP, IGMP

# %% [markdown]
# 출처: https://hahahoho5915.tistory.com/15

# %% [markdown]
# **ARP, ICMP, IGMP**

# %% [markdown]
# ---

# %% [markdown]
# 아래에 제시된 내용은 IPv6에 관한 내용이다. A,B,C,D에 알맞은 보기를 선택하시오.
#
# * IPv6
# * A비트 * B 개 = 128bit
# * 표현 C진수
# * **유니캐스트, 멀티캐스트, D**
#
# 1. 8비트, 8자리, 16진수, 애니캐스트
# 2. 8비트, 16자리,10진수, 브로드캐스트
# 3. 16비트, 8자리,16진수, 애니캐스트
# 4. 16비트, 16자리,10진수, 브로드캐스트

# %% [markdown]
# 정답> 3. **16**비트, **8**자리,**16**진수, **애니**캐스트

# %% [markdown]
# ---
