# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EA%B0%80%EC%83%81%EC%BB%B4%ED%93%A8%ED%84%B0_%EC%83%9D%EC%84%B1_Hyper_V.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 가상컴퓨터를 생성하시오
#
# 1. 이름: 네트워크관리사
# 2. 가상컴퓨터 위치: C:\Hyper-V\
# 3. 메모리: 1024MB
# 4. 가상 하드디스크 이름 : 네트워크관리사.vhd
# 5. 가상 하드디스크 위치 : C:\Hyper-V\네트워크관리사\
# 6. 가상 하드디스크 크기 : 64 GB
# 7. 나중에 운영체제 설치

# %% [markdown]
# ICQAServer 오른쪽 클릭 -> 새로만들기 -> 가상컴퓨터

# %% [markdown]
# ![화면 캡처 2021-09-22 200729.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-22 200745.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-22 200816.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-22 200833.png](data:image/png;base64,...)

# %% [markdown]
# ---
