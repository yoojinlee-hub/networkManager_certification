# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EB%A1%9C%EC%BB%AC%EB%B3%B4%EC%95%88%EC%A0%95%EC%B1%85Setting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 패스워드는 최소 10일에서 최대 20일 사용
# ![화면 캡처 2021-09-12 161628.png](data:image/png;base64,...)

# %% [markdown]
# 2. 패스워드는 3번 로그인 실패시 30분간 계정 잠금![화면 캡처 2021-09-12 161729.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# *   시스템종료: Administrators. Backup Operators
# *   시간대 변경: Administrators. LOCAL SERVICE
# *   시스템 시간 변경: Administrators

# %% [markdown]
# ![화면 캡처 2021-09-17 192523.png](data:image/png;base64,...)

# %% [markdown]
# 해당되지 않는 것 제거하기

# %% [markdown]
# ![화면 캡처 2021-09-17 192541.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-17 192604.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-17 192616.png](data:image/png;base64,...)

# %% [markdown]
# ---
