# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/IIS_FTP_Server_Setting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. FTP 사이트 이름: ICQA<br>
# 2. 실제경로 : C:\inetpub\ftproot![화면 캡처 2021-09-10 190018.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-10 190108.png](data:image/png;base64,...)

# %% [markdown]
# 3.ip주소: 192.168.100.10 , 포트 : 2121![화면 캡처 2021-09-10 190203.png](data:image/png;base64,...)

# %% [markdown]
# 4. 엑세스 허용: 익명사용자(읽기권한만)![화면 캡처 2021-09-10 190232.png](data:image/png;base64,...)

# %% [markdown]
# 5. 엑세스 거부 ip 주소![화면 캡처 2021-09-10 190317.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-10 190445.png](data:image/png;base64,...)

# %% [markdown]
# 6. 최대 연결 수 메시지![화면 캡처 2021-09-10 190604.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-10 190640.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 1. 이름 : ICQA-FTP2
# 2. ip 주소: 210.200.120.150
# 3. TCP 포트 : 21
# 4. 실제 경로: C:\
# 5. 데이터 채널 시간 제한 : 45초
# 6. 소캣 폴링 사용 안함
# 7. 최대 동시 연결 수:20

# %% [markdown]
# ![화면 캡처 2021-09-14 142005.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 142041.png](data:image/png;base64,...)

# %% [markdown]
# ***만들어진 사이트 마우스 오른쪽 -> FTP 사이트 관리 -> 고급설정***

# %% [markdown]
# ![화면 캡처 2021-09-14 142209.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 1. FTP 사이트 이름: ICQA-FTP
# 2. 실제 경로: C:\inetpub\util
# 3. ip 주소: 210.100.110.150. 포트:2121
# 4. 동시접속(최대 연결 수) : 5
# 5. 접속메시지: 한국 FTP 사이트

# %% [markdown]
# ![화면 캡처 2021-09-17 191042.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-17 191111.png](data:image/png;base64,...)

# %% [markdown]
# ICQA-FTP 오른쪽 클릭 -> FTP 사이트 관리 -> 고급설정![화면 캡처 2021-09-17 191238.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-17 191407.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-17 191432.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 두 개의 FTP 사이트 운영
# 1.
# * 이름: ICQA
# * ip 주소: 211.122.144.251
# * TCP 포트:2121
# * 권한: 모든 사용자가 읽기,쓰기 가능
# * 실제경로: c:\home\icqa
# 2.
# * 이름: Network
# * ip 주소: 211.112.144.252
# * 실제경로: C:\home\net

# %% [markdown]
# ![화면 캡처 2021-09-22 195546.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-22 195623.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-22 195647.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-22 195715.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-22 195733.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# * FTP 사이트 이름 : ICQA
# * 경로 : c:\inetpub\ftp
# * ip address: 192.168.100.10
# * 데이터 채널 시간 제한: 100
# * 최대 동시 접속: 10
# * 컨트롤 채널 시간 제한: 180
# * 이름 바꿀 때 덮어쓰기 허용
# * 접속 메시지: 한국정보통신자격협회

# %% [markdown]
# ![화면 캡처 2021-09-25 160043.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-25 160121.png](data:image/png;base64,...)

# %% [markdown]
# *새로 생성된 ICQA 오른쪽 클릭 -> FTP 사이트 관리 -> 고급설정*

# %% [markdown]
# ![화면 캡처 2021-09-25 160438.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-25 160541.png](data:image/png;base64,...)

# %% [markdown]
# ---
