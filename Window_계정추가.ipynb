# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/Window_%EA%B3%84%EC%A0%95%EC%B6%94%EA%B0%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![화면 캡처 2021-09-11 120800.png](data:image/png;base64,...)

# %% [markdown]
# 1. ID: ICQA
# 2. Password: ICQAPass
# 3. 전체이름: 전체관리자
# 4. 설명:한국정보통신자격협회
# 5. 암호 변경할 수 없음
# 6. 암호 사용기간 제한없음![화면 캡처 2021-09-11 120932.png](data:image/png;base64,...)

# %% [markdown]
# *추가된 것 확인 + 오른쪽 마우스 클릭*![화면 캡처 2021-09-11 120959.png](data:image/png;base64,...)

# %% [markdown]
# 7. 소속그룹: Administrators![화면 캡처 2021-09-11 121130.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-11 121152.png](data:image/png;base64,...)

# %% [markdown]
# 8. 로컬경로: C:\icqa![화면 캡처 2021-09-11 121417.png](data:image/png;base64,...)
