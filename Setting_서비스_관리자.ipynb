# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/Setting_%EC%84%9C%EB%B9%84%EC%8A%A4_%EA%B4%80%EB%A6%AC%EC%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <재부팅 시에도 기능이 계속 실행되도록 설정><br>
# 암호화된 파일을 NTFS **파일 시스템 볼륨**에 저장하는데 사용되는 핵심 파일 암호화 기술을 제공합니다. 이  서비스를 중지하거나 사용하지 않도록 설정하면 응용 프로그램에서 암호화된 파일에 액세스하지 못하게 됩니다.

# %% [markdown]
# * 문제에 나와있는 설명과 본문의 설명이 같은 것 찾기
# * 파일관련 -> 파일 시스템에서 찾아보기

# %% [markdown]
# ![화면 캡처 2021-09-17 193156.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-17 193227.png](data:image/png;base64,...)

# %% [markdown]
# 재부팅 시에도 기능 계속 실행 -> 시작유형: 자동

# %% [markdown]
# ---

# %% [markdown]
# NAS에서 하드디스크로 데이터 전송을 위해 iSCSI 서비스를 실행하고 재부팅 이후에서 서비스가 유지되도록 설정하시오

# %% [markdown]
# ![화면 캡처 2021-09-25 161257.png](data:image/png;base64,...)

# %% [markdown]
# 넓은 화면으로 내용과 제목을 비교해가며 찾아보자

# %% [markdown]
# ![화면 캡처 2021-09-25 161345.png](data:image/png;base64,...)

# %% [markdown]
# ---
