# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/%EB%84%A4%ED%8A%B8%EC%9B%8C%ED%81%AC_%EC%84%A4%EC%A0%95_%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **문제: 네트워크 환경에 <제시문제>와 같이 ip주소와 서브넷마스크를 추가하시오**
#
# *  ip Address:10101100.00010000.10010110.01110011
# *   Subnet Mask : 22 bit
# * Default Gateway: 192.168.100.254
# * DNS Servers: 200.100.100.200
# * 추가 Gateway: 192.168.100.253
# * 보조 DNS Servers: 201.100.100.201

# %% [markdown]
# ![화면 캡처 2021-09-06 171522.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-06 171546.png](data:image/png;base64,...)

# %% [markdown]
# *  ip Address:10101100.00010000.10010110.01110011
#
# 10000000 = 128 <br>
# 01000000 = 64 <br>
# 00100000 = 32 <br>
# 00010000 = 16 <br>
# 00001000 = 8 <br>
# 00000100 = 4 <br>
# 00000010 = 2 <br>
# 00000001 = 1 <br>
# 을 더해서 10진법으로 나타내기 -> 172.16.150.115
#
#
# *   Subnet Mask : 22 bit
#
# 2진수가 앞에서부터 1로 채워진다고 보면 됨 (총 24bit)<br>
# 11111111.11111111.11111100.00000000 -> 255.255.252.0

# %% [markdown]
# 추가 GateWay는 고급에서 설정한다<br>![화면 캡처 2021-09-06 171604.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 문제: 관리도구에 <제시문제>와 같이 DNS서버를 설정하시오
# <br>
# @ IN *SOA* ns**.icqa.or.kr** admin**.icqa.or.kr** ( 10 ; Serial. 15분 ; Refresh. 10분; Retry. 1일 ; Expire. 1시간;Minimum)
# <br>
#
#
#
# **www** *IN A* **192.168.100.20** <br>
# **ftp** *IN CNAME* **www**

# %% [markdown]
# DNS에서 실행
#
# ![화면 캡처 2021-09-06 174222.png](data:image/png;base64,...)

# %% [markdown]
# 정방향 조회 영역에서 오른쪽 키<br>![화면 캡처 2021-09-06 173326.png](data:image/png;base64,...)

# %% [markdown]
# 필요없는 것은 넘기고, 이름 설정<br>
# ***문제에서 공통된 icqa.or.kr를 입력!!***
# ![화면 캡처 2021-09-06 173426.png](data:image/png;base64,...)

# %% [markdown]
# 새로 만들어진 icqa.or.kr를 오른쪽 클릭해서 속성에 들어가서 SOA 설정 <br>![화면 캡처 2021-09-06 173629.png](data:image/png;base64,...)

# %% [markdown]
# icqa.or.kr를 오른쪽 클릭해서 A 설정![화면 캡처 2021-09-06 173750.png](data:image/png;base64,...)

# %% [markdown]
# icqa를 오른쪽 클릭해서 CNAME 설정![화면 캡처 2021-09-06 173838.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 문제> 제시문제와 같이 네트워크 환경을 설정하시오

# %% [markdown]
# 1. ip : **네트워크 할당 주소들 중 가장 큰 주소** -> 마지막이 255 바로 전 -> 254
# 2. gateway:192.168.10.1
# 3. 주 dns 서버: 201.100.100.1
# 4. 보조 dns 서버:201.100.100.2<br>![화면 캡처 2021-09-13 114343.png](data:image/png;base64,...)
