# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/Router_encapsulation_%EC%84%A4%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Router2의 serial 2/0에 frame relay방식으로 캡슐화 하시오

# %% [markdown]
# ![화면 캡처 2021-09-26 120330.png](data:image/png;base64,...)

# %% [markdown]
# 힌트>interface로 들어간 후 ?를 치면 가능한 명령어가 나온다

# %% [markdown]
# ![화면 캡처 2021-09-26 120351.png](data:image/png;base64,...)

# %% [markdown]
# ---
