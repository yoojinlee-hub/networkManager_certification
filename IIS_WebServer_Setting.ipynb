# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/IIS_WebServer_Setting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***꼭 x로 나가기 전에 다른 곳을 눌러서 저장하자!!!***

# %% [markdown]
# ![화면 캡처 2021-09-11 115543.png](data:image/png;base64,...)

# %% [markdown]
# 1. 웹사이트 이름: ICQA
# 2. 실제 경로: C:\inetpub\ftproot
# 3. 웹사이트 ip주소: 192.168.100.10
# 4. 포트: 80
# 5. 호스트이름: http://www.icqa.or.kr
# ![화면 캡처 2021-09-11 115709.png](data:image/png;base64,...)

# %% [markdown]
# 6. 엑세스 허용 ip 주소: 192.168.100.0/24![화면 캡처 2021-09-11 115821.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-11 115934.png](data:image/png;base64,...)
