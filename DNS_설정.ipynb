# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/DNS_%EC%84%A4%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <시간단위: 초><br>
# icqa.or.kr.dns for icqa.or.kr.zone.<br>
# @ IN SOA ns.icqa.or.kr master.icqa.or.kr( 12:serial number, 900: refresh, 600:retry, 86400: expire, 7200:minimum TTL)<br>
# : Zone records<br>
# mail   A  211.111.144.241<br>
# network A 211.111.144.240

# %% [markdown]
# ![화면 캡처 2021-09-14 140207.png](data:image/png;base64,...)

# %% [markdown]
# icqa.or.kr 오른쪽 클릭 -> 속성

# %% [markdown]
# ![화면 캡처 2021-09-14 140516.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 140602.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 140641.png](data:image/png;base64,...)

# %% [markdown]
# ---
