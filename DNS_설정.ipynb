# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/networkManager_certification/blob/main/DNS_%EC%84%A4%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <시간단위: 초><br>
# icqa.or.kr.dns for icqa.or.kr.zone.<br>
# @ IN SOA ns.icqa.or.kr master.icqa.or.kr( 12:serial number, 900: refresh, 600:retry, 86400: expire, 7200:minimum TTL)<br>
# : Zone records<br>
# mail   A  211.111.144.241<br>
# network A 211.111.144.240

# %% [markdown]
# ![화면 캡처 2021-09-14 140207.png](data:image/png;base64,...)

# %% [markdown]
# icqa.or.kr 오른쪽 클릭 -> 속성

# %% [markdown]
# ![화면 캡처 2021-09-14 140516.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 140602.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-14 140641.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 단위: 초
#
# 1. 주소: icqa.or.kr
# 2. 일련번호: 10
# 3. 주 서버: ns.icqa.or.kr
# 4. 책임자: admin.icqa.or.kr
# 5. 새로고침 : 600
# 6. 다시시도간격: 800
# 7. 다음날짜 이후 만료: 48000
# 8. 최소 TTL: 3600

# %% [markdown]
# ![화면 캡처 2021-09-17 191835.png](data:image/png;base64,...)

# %% [markdown]
# icqa.or.kr 마우스 오른쪽 -> 속성 -> SOA설정

# %% [markdown]
# ![화면 캡처 2021-09-17 192021.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# DNS 서버 구축 <br>![화면 캡처 2021-09-20 113236.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 113358.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 113502.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 113556.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 113628.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-20 113638.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# DNS 설정<br>
# @ IN SOA ns.icqa.or.kr master.icqa.or.kr <br>
# 15 : serial number <br>
# 1500: refresh <br>
# 800: retry<br>
# 72000 : expire<br>
# 4800: minimum<br>
# TTL : Zone NS records

# %% [markdown]
# ![화면 캡처 2021-09-25 161711.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-09-25 161935.png](data:image/png;base64,...)

# %% [markdown]
# ---
